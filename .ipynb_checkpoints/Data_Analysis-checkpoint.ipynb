# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('classes.csv',header=None)
df
# Out:
#                   0    1
# 0      001_0001.jpg    1
# 1      001_0002.jpg    1
# 2      001_0003.jpg    1
# 3      001_0004.jpg    1
# 4      001_0005.jpg    1
# 5      001_0006.jpg    1
# 6      001_0007.jpg    1
# 7      001_0008.jpg    1
# 8      001_0009.jpg    1
# 9      001_0010.jpg    1
# 10     001_0011.jpg    1
# 11     001_0012.jpg    1
# 12     001_0013.jpg    1
# 13     001_0014.jpg    1
# 14     001_0015.jpg    1
# 15     001_0016.jpg    1
# 16     001_0017.jpg    1
# 17     001_0018.jpg    1
# 18     001_0019.jpg    1
# 19     001_0020.jpg    1
# 20     001_0021.jpg    1
# 21     001_0022.jpg    1
# 22     001_0023.jpg    1
# 23     001_0024.jpg    1
# 24     001_0025.jpg    1
# 25     001_0026.jpg    1
# 26     001_0027.jpg    1
# 27     001_0028.jpg    1
# 28     001_0029.jpg    1
# 29     001_0030.jpg    1
# ...             ...  ...
# 30577  257_0798.jpg  257
# 30578  257_0799.jpg  257
# 30579  257_0800.jpg  257
# 30580  257_0801.jpg  257
# 30581  257_0802.jpg  257
# ...

# %%
counts = df.groupby(1).count().sort_values(0,ascending=False).reset_index().rename(columns={1:'class',0:'frequency'})[:20]
plt.figure(figsize=(10,6))
sns.barplot(data=counts,x='class',y='frequency',order=counts['class'],color='#679efc')
plt.title('Top 20 Classes by Frequency')
# Out:
# C:\Users\ibiyt\Anaconda3\lib\site-packages\seaborn\categorical.py:1460: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)
# Text(0.5,1,'Top 20 Classes by Frequency')
