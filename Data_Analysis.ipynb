# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import json
# %matplotlib inline

# %% [markdown]
# ## Clustering Analysis

# %%
df = pd.DataFrame.from_records(json.load(open('D3_inputs/test_layer36.json','r')))
df
# Out:
#       HDBSCAN               filename         x         y
# 0          -1    test/1/001_0003.jpg  0.235722  0.205317
# 1          -1    test/1/001_0007.jpg  0.229130  0.849728
# 2          -1    test/1/001_0016.jpg  1.259777  0.764371
# 3          -1    test/1/001_0034.jpg  0.636470  0.746370
# 4          -1    test/1/001_0040.jpg  1.325634 -0.215840
# 5          -1    test/1/001_0041.jpg  0.273333  0.105541
# 6          -1    test/1/001_0043.jpg  0.560432  0.714568
# 7          -1    test/1/001_0095.jpg -0.346250  0.168325
# 8          -1   test/10/010_0003.jpg -0.168488 -0.906013
# 9          -1   test/10/010_0033.jpg  0.318023 -0.862272
# 10         -1   test/10/010_0059.jpg  0.309599 -0.452283
# 11         -1   test/10/010_0064.jpg -0.127969 -0.639123
# 12         -1   test/10/010_0072.jpg -0.276307 -0.999411
# 13         -1   test/10/010_0079.jpg -0.987835 -0.398357
# 14         -1  test/100/100_0002.jpg  0.993560  0.148175
# ...

# %%
df['HDBSCAN'].max()
# Out:
# 2
